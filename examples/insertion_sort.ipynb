# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
# %matplotlib inline
import profiler
from insertion_sort import insertion_sort

# %%
print 'Insertion Sort Complexity'
profiler.profile_and_plot(insertion_sort, num_runs=100, step=1)
# Out:
# Insertion Sort Complexity
# <ggplot: (282104673)>
