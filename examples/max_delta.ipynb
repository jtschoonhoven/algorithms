# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
# %matplotlib inline
import profiler
from max_delta import max_delta

# %%
print 'Max Delta Complexity'
profiler.profile_and_plot(max_delta, num_runs=100, step=1)
# Out:
# Max Delta Complexity
# <ggplot: (286802093)>
