# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
# %matplotlib inline
import profiler
from merge_sort import merge_sort

# %%
print 'Merge Sort Complexity'
profiler.profile_and_plot(merge_sort, num_runs=100, step=1)
# Out:
# Merge Sort Complexity
# <ggplot: (284187249)>
