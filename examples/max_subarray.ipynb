# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
# %matplotlib inline
import profiler
from max_subarray import max_subarray

# %%
print 'Max Subarray Complexity'
profiler.profile_and_plot(max_subarray, num_runs=100, step=1)
# Out:
# Max Subarray Complexity
# <ggplot: (274039977)>
